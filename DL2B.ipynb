# %%
# !pip install yellowbrick
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting yellowbrick
#   Downloading yellowbrick-1.5-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.2 in c:\users\makar\appdata\roaming\python\python312\site-packages (from yellowbrick) (3.10.9)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\makar\appdata\roaming\python\python312\site-packages (from yellowbrick) (1.17.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in c:\users\makar\appdata\roaming\python\python312\site-packages (from yellowbrick) (1.8.0)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\makar\appdata\roaming\python\python312\site-packages (from yellowbrick) (1.26.4)
# Requirement already satisfied: cycler>=0.10.0 in c:\programdata\anaconda3\lib\site-packages (from yellowbrick) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\makar\appdata\roaming\python\python312\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\makar\appdata\roaming\python\python312\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (26.2)
# Requirement already satisfied: pillow>=8 in c:\programdata\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (10.4.0)
# Requirement already satisfied: pyparsing>=3 in c:\programdata\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (2.9.0.post0)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\makar\appdata\roaming\python\python312\site-packages (from scikit-learn>=1.0.0->yellowbrick) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn>=1.0.0->yellowbrick) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\makar\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.17.0)
# Downloading yellowbrick-1.5-py3-none-any.whl (282 kB)
# Installing collected packages: yellowbrick
# Successfully installed yellowbrick-1.5

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

# %%
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/letter-recognition/letter-recognition.data
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import pandas as pd

url = "https://archive.ics.uci.edu/ml/machine-learning-databases/letter-recognition/letter-recognition.data"

dataset = pd.read_csv(url, header=None)

# %%
X = dataset.iloc[:, 1:17]
Y = dataset.iloc[:, 0].values.ravel() # FIXED (important)

# %%
X_train, X_validation, Y_train, Y_validation = train_test_split(
    X, Y, test_size=0.2, random_state=42
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 X_train, X_validation, Y_train, Y_validation = train_test_split(
#       2     X, Y, test_size=0.2, random_state=42
#       3 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\model_selection\_split.py:2950, in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2947 xp, _, device = get_namespace_and_device(arrays[0])
#    2948 train, test = move_to(train, test, xp=xp, device=device)
# -> 2950 return list(
#    2951     chain.from_iterable(
#    2952         (_safe_indexing(a, train), _safe_indexing(a, test)) for a in arrays
#    2953     )
#    2954 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\model_selection\_split.py:2952, in <genexpr>(.0)
#    2947 xp, _, device = get_namespace_and_device(arrays[0])
#    2948 train, test = move_to(train, test, xp=xp, device=device)
#    2950 return list(
#    2951     chain.from_iterable(
# -> 2952         (_safe_indexing(a, train), _safe_indexing(a, test)) for a in arrays
#    2953     )
#    2954 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\_indexing.py:375, in _safe_indexing(X, indices, axis)
#     367     raise warnings.warn(
#     368         message="A data object with support for the dataframe interchange protocol"
#     369         "was passed, but scikit-learn does currently not know how to handle this "
#     370         "kind of data. Some array/list indexing will be tried.",
#     371         category=UserWarning,
#     372     )
#     374 if hasattr(X, "shape"):
# --> 375     return _array_indexing(X, indices, indices_dtype, axis=axis)
#     376 else:
#     377     return _list_indexing(X, indices, indices_dtype)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\_indexing.py:63, in _array_indexing(array, key, key_dtype, axis)
#      61 if isinstance(key, tuple):
#      62     key = list(key)
# ---> 63 return array[key, ...] if axis == 0 else array[:, key]
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\arrow\array.py:799, in ArrowExtensionArray.__getitem__(self, item)
#     791     elif (
#     792         item.stop is not None
#     793         and item.stop < -len(self)
#     794         and item.step is not None
#     795         and item.step < 0
#     796     ):
#     797         item = slice(item.start, None, item.step)
# --> 799 value = self._pa_array[item]
#     800 if isinstance(value, pa.ChunkedArray):
#     801     result = self._from_pyarrow_array(value)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pyarrow\table.pxi:306, in pyarrow.lib.ChunkedArray.__getitem__()
#
# TypeError: only integer scalar arrays can be converted to a scalar index

# %%
import pandas as pd

url = "https://archive.ics.uci.edu/ml/machine-learning-databases/letter-recognition/letter-recognition.data"

dataset = pd.read_csv(url, header=None)

X = dataset.iloc[:, 1:17].to_numpy()
Y = dataset.iloc[:, 0].to_numpy()

# %%
X_train, X_validation, Y_train, Y_validation = train_test_split(
    X, Y, test_size=0.2, random_state=42
)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_validation = scaler.transform(X_validation)

# %%
mlp = MLPClassifier(
    hidden_layer_sizes=(100, 100),
    max_iter=300,
    activation='relu',
    solver='adam',
    random_state=42
)

# %%
mlp.fit(X_train, Y_train)
# Out:
# MLPClassifier(hidden_layer_sizes=(100, 100), max_iter=300, random_state=42)

# %%
from yellowbrick.classifier import ConfusionMatrix

classes = list("ABCDEFGHIJKLMNOPQRSTUVWXYZ")

cm = ConfusionMatrix(mlp, classes=classes)
cm.fit(X_train, Y_train)
cm.score(X_validation, Y_validation)
cm.show()
# Out:
# ---------------------------------------------------------------------------
# YellowbrickTypeError                      Traceback (most recent call last)
# Cell In[12], line 5
#       1 from yellowbrick.classifier import ConfusionMatrix
#       3 classes = list("ABCDEFGHIJKLMNOPQRSTUVWXYZ")
# ----> 5 cm = ConfusionMatrix(mlp, classes=classes)
#       6 cm.fit(X_train, Y_train)
#       7 cm.score(X_validation, Y_validation)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\yellowbrick\classifier\confusion_matrix.py:150, in ConfusionMatrix.__init__(self, estimator, ax, sample_weight, percent, classes, encoder, cmap, fontsize, is_fitted, force_model, **kwargs)
#     136 def __init__(
#     137     self,
#     138     estimator,
#    (...)
#     148     **kwargs
#     149 ):
# --> 150     super(ConfusionMatrix, self).__init__(
#     151         estimator,
#     152         ax=ax,
#     153         classes=classes,
#     154         encoder=encoder,
#     155         is_fitted=is_fitted,
#     156         force_model=force_model,
#     157         **kwargs
#     158     )
#     160     # Visual parameters
#     161     self.fontsize = fontsize
#
# File ~\AppData\Roaming\Python\Python312\site-packages\yellowbrick\classifier\base.py:122, in ClassificationScoreVisualizer.__init__(self, estimator, ax, fig, classes, encoder, is_fitted, force_model, **kwargs)
#     109 def __init__(
#     110     self,
#     111     estimator,
#    (...)
#     119 ):
#     120     # A bit of type checking
#     121     if not force_model and not isclassifier(estimator):
# --> 122         raise YellowbrickTypeError(
#     123             "This estimator is not a classifier; "
#     124             "try a regression or clustering score visualizer instead!"
#     125         )
#     127     # Initialize the super method.
#     128     super(ClassificationScoreVisualizer, self).__init__(
#     129         estimator, ax=ax, fig=fig, is_fitted=is_fitted, **kwargs
#     130     )
#
# YellowbrickTypeError: This estimator is not a classifier; try a regression or clustering score visualizer instead!
